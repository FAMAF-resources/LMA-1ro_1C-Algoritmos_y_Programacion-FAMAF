# %% [markdown]
# ##Práctico 5.1
# #Listas

# %% [markdown]
# **Ejercicio 1.** Ejercicios 10.1 a 10.14 de las páginas 323 y 324 del libro “Introduction to programming  using Python” de Y. Daniel Liang.

# %%
import random

# %%
#10.1
lista1 = []
lista2 = [1, 32, 2]

#10.2
#Hay 6 elementos, la primera posicion es la 0, lst[2] = 12, lst[-2] = 14

#10.3
lista3 = [30, 1, 12, 14, 10, 0]
lista3.append(40)
print('A',lista3)
lista3.insert(1, 43)
print('B', lista3)
lista3.extend([1, 43])
print('C', lista3)
lista3.remove(1)
print('D', lista3)
lista3.pop(2)
print('E', lista3)
lista3.pop()
print('F', lista3)
lista3.sort()
print('G', lista3)
lista3.reverse()
print('H', lista3)
random.shuffle(lista3)
print('I', lista3)

#10.4
lista4 = [30, 1, 2, 1, 0]

print(lista4.index(1))
print(lista4.count(1))
print('Longitud', len(lista4))
print('Maximo',max(lista4))
print('minimo', min(lista4))
print('Suma', sum(lista4))

#10.5
lista5, lista6 = [30, 1, 2, 1, 0], [1, 21, 13]
print(lista5 + lista6)
print(lista5 * 2)
print(2 * lista5)

#10.6
print(lista7)

#10.7
list1, list2 = [30, 1, 2, 1, 0], [1, 21, 13]
a = list1 < list2
b =list1 <= list2
c =list1 == list2
d =list1 != list2
e =list1 > list2
f =list1 >= list2
# Out:
# A [30, 1, 12, 14, 10, 0, 40]
# B [30, 43, 1, 12, 14, 10, 0, 40]
# C [30, 43, 1, 12, 14, 10, 0, 40, 1, 43]
# D [30, 43, 12, 14, 10, 0, 40, 1, 43]
# E [30, 43, 14, 10, 0, 40, 1, 43]
# F [30, 43, 14, 10, 0, 40, 1]
# G [0, 1, 10, 14, 30, 40, 43]
# H [43, 40, 30, 14, 10, 1, 0]
# I [1, 14, 10, 0, 40, 43, 30]
# 1
# 2
# Longitud 5
# Maximo 30
# minimo 0
# Suma 34
# [30, 1, 2, 1, 0, 1, 21, 13]
# [30, 1, 2, 1, 0, 30, 1, 2, 1, 0]
# [30, 1, 2, 1, 0, 30, 1, 2, 1, 0]
# [-2]
# [2, 3, 4, 1, 5]

# %% [markdown]
# **Ejercicio 3.** Ejercicio 10.17 de la página 334.

# %% [markdown]
# **Ejercicio 4.** Predecir y explicar el porqué del comportamiento de cada uno de los programas de los ejercicios 10.18 (a) y (b) y 10.19 (a) y (b).

# %% [markdown]
# **Ejercicio 5.**
# Definir una función que dado un número natural `n >= 2` devuelve la lista de todos los números primos entre `2` y `n-1`. Pueden usar que `list(range(2,n))` es la lista de todos los números entre `2` y `n-1`.

# %% [markdown]
# **Ejercicio 6.** Escribir una función que recibe una lista y dos posiciones de la lista e intercambia los valores que hay en esas posiciones. No lleva `return` porque modifica la propia lista que recibe como parámetro. Acá podemos usar el `assert` para asegurarnos que las posiciones pertenezcan a la lista.

# %% [markdown]
# **Ejercicio 7.** Escribir una función que devuelve el menor elemento de la lista sin usar la función que python provee para eso.

# %% [markdown]
# **Ejercicio 8.** Igual que el ejercicio anterior, pero en lugar de devolver el menor elemento devuelve la posición que ese elemento tiene en la lista.

# %% [markdown]
# **Ejercicio 9.** Escribir una función que devuelve el menor elemento de la lista. Pero no de toda la lista sino de la lista a partir de un cierto índice: esta función recibe la lista y un índice de la lista y devuelve el menor elemento desde ese índice en adelante.

# %% [markdown]
# **Ejercicio 10.** Igual que el ejercicio anterior pero devuelve la posición de ese elemento.

# %% [markdown]
# **Ejercicio 11.** Escribir una función que recibe una lista y determina si está o no ordenada de menor a mayor (puede tener repeticiones). Devuelve un valor lógico.

# %% [markdown]
# **Ejercicio 12.** Escribir una función que recibe dos listas y determina si una es permutación de otra. Es bastante difícil. Una manera es comprobar que tengan igual longitud y en tal caso comprobar que los elementos de una de ellas están en la otra igual número de veces.
