# %% [markdown]
# #Práctico 6.2
# ##Recursión sobre listas

# %% [markdown]
# **Ejercicio 1.** Dar una versión recursiva de la definición de mínimo de una lista.

# %% [markdown]
# **Ejercicio 2.** Dar una versión recursiva de la definición de son_todos_primos de una lista.

# %% [markdown]
# **Ejercicio 3.** Dar una versión recursiva de la búsqueda lineal. El linear search del libro está en la página 338.

# %% [markdown]
# **Ejercicio 4.** Dar una versión recursiva para el caso en que la lista se asume ordenada

# %% [markdown]
# **Ejercicio 5.** Dar una versión recursiva de la búsqueda binaria: debe llevar dos parámetros adicionales que indican entre cuáles posiciones de la lista se está buscando.
